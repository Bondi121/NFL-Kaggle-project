# %% [markdown]
# Overview
# The National Football League (NFL) is back with another Big Data Bowl, where contestants use Next Gen Stats player tracking data to generate actionable, creative, and novel stats. Previous iterations have analyzed running backs, defensive backs, special teams, and pass rush plays, and have generated metrics that have been used on television and by NFL teams. This year's competition focuses on one area that we have yet to … tackle …

# %% [markdown]
# Understand the Problem and Objectives: Clearly define what the challenge is asking. What specific aspect of the NFL game are we focusing on this year? Understanding the objective is crucial for guiding our analysis.
#
# Data Exploration: Once we have the dataset, we'll need to explore it to understand its structure, the type of data it includes (e.g., player tracking data, game situations, etc.), and any potential quality issues (missing values, outliers, etc.).
#
# Feature Engineering: Based on our understanding of the problem, we can create new features that might be relevant for our analysis. This step is often crucial in sports analytics.
#
# Analytical Approach: Decide on the analytical methods or models that are most appropriate for the task. This could range from statistical analysis to more complex machine learning models, depending on the challenge's requirements.
#
# Model Building and Validation: If the challenge involves predictive modeling, we'll build and validate our model(s), tuning parameters as necessary to improve performance.
#
# Insight Generation: The key to these challenges is not just building a model but generating actionable and novel insights. This step involves interpreting the results of our analysis and considering how they can be applied in a practical, real-world NFL context.
#
# Presentation and Visualization: Finally, presenting our findings in a clear, concise, and compelling way is crucial. Effective visualizations can help communicate complex data and insights

# %% [markdown]
# 2024 Theme: Tackling
# American football is a complex sport, but once an offensive player receives a handoff or catches a pass, all 11 defenders focus on one task -- tackle that ball carrier as soon as possible. Conversely, the ball carrier's role is to advance the ball down the field to gain as much yardage as possible until he is tackled, scores, or runs out of bounds.
#
# This year's competition offers up a general goal — create metrics that assign value to elements of tackling. You can access the NFL’s Next Gen Stats data as in previous competitions. This year's player tracking includes data from Weeks 1-9 of the 2022 NFL season. Data will show the location, speed, and acceleration of all 22 players on the field, along with football location. Additional PFF scouting data and NFL advanced stats such as expected points and win probability are also included.
#
# Top winners will be invited to present their results to the NFL, where one team will receive an additional prize. NFL teams may also use the most useful new metrics or analysis to evaluate both their offensive and defensive players.

# %% [markdown]
#  Defining Metrics for Tackling
# First, we need to define what aspects of tackling could be quantified and are valuable for analysis. This can include:
#
# Efficiency: How quickly and effectively a defender makes a tackle after a catch or handoff.
# Impact: Assessing the impact of a tackle in terms of preventing yardage gain, causing fumbles, etc.
# Technique: Evaluating the form and approach of a tackle, which might be more subjective and require scouting data.
# Positional Analysis: How different positions contribute to tackling effectiveness.
# 2. Data Exploration
# We'll need to thoroughly explore the provided data to understand the variables at our disposal. This involves:
#
# Understanding Tracking Data: Analyzing player positions, speed, and acceleration to understand movement patterns before and during tackles.
# PFF Scouting Data: Integrating scouting insights which may offer qualitative assessments of tackles.
# Advanced Stats: Incorporating expected points and win probability to understand the situational importance of tackles.
# 3. Feature Engineering
# Based on our initial analysis, we can engineer features that are likely to be relevant for tackling metrics. This might include:
#
# Time to Tackle: Time taken from the initiation of a play to the tackle.
# Yards After Contact: How much yardage is gained after initial contact is made.
# Tackle Impact Score: A composite metric based on factors like speed reduction, direction change, etc.
# 4. Analytical Approach
# We can employ various analytical techniques depending on the metric:
#
# Statistical Analysis: For more straightforward metrics like efficiency or impact.
# Machine Learning Models: If we aim to predict outcomes or create more complex metrics.
# Spatial Analysis: To understand player positioning and movements on the field.
# 5. Model Building and Validation
# For predictive models or complex metrics, we'll need to:
#
# Build Models: Using relevant features to predict or quantify aspects of tackling.
# Validate and Tune: Ensuring our models are accurate and robust against overfitting.
# 6. Insight Generation
# This involves interpreting the data and metrics to provide valuable insights such as:
#
# Player and Team Evaluation: Assessing tackling effectiveness at individual and team levels.
# Tactical Insights: Understanding how tackling strategies impact game outcomes.
# 7. Presentation and Visualization
# Finally, presenting our findings in an understandable and visually appealing manner is crucial. This could include:
#
# Interactive Visualizations: To demonstrate player movements and tackle effectiveness.
# Graphs and Charts: Illustrating key metrics and insights.
# Data Access and Preparation
# To begin, you'll need to download the dataset from the Kaggle competition page. Once you have the data, we can start with data exploration and preliminary analysis. If you can share specific data points or aspects you're interested in, we can dive deeper into those areas.

# %% [markdown]
# Examples to consider
# Your challenge is generating actionable, practical, and novel insights from player tracking data corresponding to tackling. Examples include, but are not limited to:
#
# Predictions of tackle time, probability, and/or location
# Tackle range: angle of pursuit, speed and acceleration, closing speed
# Player evaluation (e.g, yards saved, tackle value, missed tackles)
# Credit assignment (e.g, one player makes a tackle because of another players, blocks shed, area of influence)
# Tackle type (solo vs gang, open field vs in the trenches, etc)
# Team and player roles and responsibilities (setting the edge, filling gaps, etc)
# Note that the above list is not exhaustive, and we encourage participants to be creative with their submissions.

# %% [markdown]
# Evaluation
# Submission tracks
# Participants will select one of three tracks in which to submit.
#
# Undergraduate track. This is open only to groups or individuals composed entirely of undergraduate students. Verification may be required to prove eligibility.
# Metric track. Create a metric to assess performance and/or strategy. You may focus on offensive or defensive players, teams, or individuals.
# Coaching presentation track. This track aims to analyze and present data in a submission designed for coaches. We encourage participants interested in this track to partner with a coach (or current/former player), though this isn’t required.
# All submissions must explicitly state which track they are submitting to, and participants may not submit to multiple tracks.

# %% [markdown]
# Scoring
# An entry to the competition consists of a Notebook submission that is evaluated on the following four components, where 0 is the lowest and 10 is the highest.
#
# Football Score (30%):
#
# Would NFL teams (or the league office) be able to use these results on a week-to-week basis?
# Does the analysis account for variables that make football data complex?
# Are the ideas unique?
# Data Science Score (30%):
#
# Is the work correct?
# Are claims backed up by data?
# Are the statistical models appropriate given the data?
# Are the analytical applications innovative?
# Report Score (20%):
#
# Is the report well-written?
# Is the report easy to follow?
# Is the motivation (metric, player evaluation, etc) clearly defined?
# Data Visualization Score (20%)
#
# Are the charts and tables provided accessible?
# Are the charts and tables accurate?
# Are the charts and tables innovative?
# Judges will consist of analytics staffers that are working for (i) the 32 NFL teams, or (ii) player tracking vendors that work with NFL teams. Scores will be summarized using a weighed average (see above for each weight).

# %% [markdown]
# Notebook requirements
# Notebooks should contain at most 2,000 words and less than ten tables/figures. Submissions will not be penalized for any number of words or figures under this limit. Participants are encouraged to show statistical code if it helps readers better understand their analyses. However, most code should be hidden in the Appendix.
#
# All notebooks submitted must be made public on or before the submission deadline to be eligible. If submitting as a team, all team members must be listed as collaborators on all notebooks submitted.
#
# Any notebook that doesn’t use the player tracking data will not be scored.
#
# This competition is specifically intended to analyze tackling strategy. Analysis of injuries resulting from tackles is not in scope for this particular project.

# %%
import pandas as pd
import os


# Load each CSV file into a separate DataFrame
games_df = pd.read_csv('games.csv')
players_df = pd.read_csv('players.csv')
plays_df = pd.read_csv('plays.csv')
tackles_df = pd.read_csv('tackles.csv')
tracking_week_1_df = pd.read_csv('tracking_week_1.csv')
tracking_week_2_df = pd.read_csv('tracking_week_2.csv')
tracking_week_3_df = pd.read_csv('tracking_week_3.csv')
tracking_week_4_df = pd.read_csv('tracking_week_4.csv')
tracking_week_5_df = pd.read_csv('tracking_week_5.csv')
tracking_week_6_df = pd.read_csv('tracking_week_6.csv')
tracking_week_7_df = pd.read_csv('tracking_week_7.csv')
tracking_week_8_df = pd.read_csv('tracking_week_8.csv')
tracking_week_9_df = pd.read_csv('tracking_week_9.csv')

# %%
games_df.head()
# Out:
#        gameId  season  week    gameDate gameTimeEastern homeTeamAbbr  \
# 0  2022090800    2022     1  09/08/2022        20:20:00           LA
# 1  2022091100    2022     1  09/11/2022        13:00:00          ATL
# 2  2022091101    2022     1  09/11/2022        13:00:00          CAR
# 3  2022091102    2022     1  09/11/2022        13:00:00          CHI
# 4  2022091103    2022     1  09/11/2022        13:00:00          CIN
#
#   visitorTeamAbbr  homeFinalScore  visitorFinalScore
# 0             BUF              10                 31
# 1              NO              26                 27
# 2             CLE              24                 26
# 3              SF              19                 10
# 4             PIT              20                 23

# %%
games_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136 entries, 0 to 135
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gameId             136 non-null    int64
#  1   season             136 non-null    int64
#  2   week               136 non-null    int64
#  3   gameDate           136 non-null    object
#  4   gameTimeEastern    136 non-null    object
#  5   homeTeamAbbr       136 non-null    object
#  6   visitorTeamAbbr    136 non-null    object
#  7   homeFinalScore     136 non-null    int64
#  8   visitorFinalScore  136 non-null    int64
# dtypes: int64(5), object(4)
# memory usage: 9.7+ KB

# %%
players_df.head()
# Out:
#        gameId  playId    nflId   displayName  frameId  \
# 0  2022110300      55  38542.0  Fletcher Cox        1
# 1  2022110300      55  38542.0  Fletcher Cox        2
# 2  2022110300      55  38542.0  Fletcher Cox        3
# 3  2022110300      55  38542.0  Fletcher Cox        4
# 4  2022110300      55  38542.0  Fletcher Cox        5
#
#                          time  jerseyNumber club playDirection      x      y  \
# 0  2022-11-03 20:16:30.400000          91.0  PHI         right  35.31  21.25
# 1  2022-11-03 20:16:30.500000          91.0  PHI         right  35.30  21.25
# 2  2022-11-03 20:16:30.599999          91.0  PHI         right  35.29  21.25
# 3  2022-11-03 20:16:30.700000          91.0  PHI         right  35.31  21.24
# 4  2022-11-03 20:16:30.799999          91.0  PHI         right  35.31  21.25
#
#       s     a   dis       o     dir event
# 0  0.25  0.21  0.01  275.05  263.18   NaN
# 1  0.21  0.20  0.02  270.08  264.09   NaN
# 2  0.17  0.18  0.01  267.61  264.78   NaN
# ...

# %%
players_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1683 entries, 0 to 1682
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   nflId        1683 non-null   int64
#  1   height       1683 non-null   object
#  2   weight       1683 non-null   int64
#  3   birthDate    1204 non-null   object
#  4   collegeName  1683 non-null   object
#  5   position     1683 non-null   object
#  6   displayName  1683 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 92.2+ KB

# %%
plays_df.head()
# Out:
#        gameId  playId    nflId   displayName  frameId  \
# 0  2022110300      55  38542.0  Fletcher Cox        1
# 1  2022110300      55  38542.0  Fletcher Cox        2
# 2  2022110300      55  38542.0  Fletcher Cox        3
# 3  2022110300      55  38542.0  Fletcher Cox        4
# 4  2022110300      55  38542.0  Fletcher Cox        5
#
#                          time  jerseyNumber club playDirection      x      y  \
# 0  2022-11-03 20:16:30.400000          91.0  PHI         right  35.31  21.25
# 1  2022-11-03 20:16:30.500000          91.0  PHI         right  35.30  21.25
# 2  2022-11-03 20:16:30.599999          91.0  PHI         right  35.29  21.25
# 3  2022-11-03 20:16:30.700000          91.0  PHI         right  35.31  21.24
# 4  2022-11-03 20:16:30.799999          91.0  PHI         right  35.31  21.25
#
#       s     a   dis       o     dir event
# 0  0.25  0.21  0.01  275.05  263.18   NaN
# 1  0.21  0.20  0.02  270.08  264.09   NaN
# 2  0.17  0.18  0.01  267.61  264.78   NaN
# ...

# %%
plays_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12486 entries, 0 to 12485
# Data columns (total 35 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   gameId                            12486 non-null  int64
#  1   playId                            12486 non-null  int64
#  2   ballCarrierId                     12486 non-null  int64
#  3   ballCarrierDisplayName            12486 non-null  object
#  4   playDescription                   12486 non-null  object
#  5   quarter                           12486 non-null  int64
#  6   down                              12486 non-null  int64
#  7   yardsToGo                         12486 non-null  int64
#  8   possessionTeam                    12486 non-null  object
#  9   defensiveTeam                     12486 non-null  object
#  10  yardlineSide                      12319 non-null  object
# ...

# %%
tackles_df.head()
# Out:
#        gameId  playId    nflId   displayName  frameId  \
# 0  2022110300      55  38542.0  Fletcher Cox        1
# 1  2022110300      55  38542.0  Fletcher Cox        2
# 2  2022110300      55  38542.0  Fletcher Cox        3
# 3  2022110300      55  38542.0  Fletcher Cox        4
# 4  2022110300      55  38542.0  Fletcher Cox        5
#
#                          time  jerseyNumber club playDirection      x      y  \
# 0  2022-11-03 20:16:30.400000          91.0  PHI         right  35.31  21.25
# 1  2022-11-03 20:16:30.500000          91.0  PHI         right  35.30  21.25
# 2  2022-11-03 20:16:30.599999          91.0  PHI         right  35.29  21.25
# 3  2022-11-03 20:16:30.700000          91.0  PHI         right  35.31  21.24
# 4  2022-11-03 20:16:30.799999          91.0  PHI         right  35.31  21.25
#
#       s     a   dis       o     dir event
# 0  0.25  0.21  0.01  275.05  263.18   NaN
# 1  0.21  0.20  0.02  270.08  264.09   NaN
# 2  0.17  0.18  0.01  267.61  264.78   NaN
# ...

# %%
tackles_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17426 entries, 0 to 17425
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gameId            17426 non-null  int64
#  1   playId            17426 non-null  int64
#  2   nflId             17426 non-null  int64
#  3   tackle            17426 non-null  int64
#  4   assist            17426 non-null  int64
#  5   forcedFumble      17426 non-null  int64
#  6   pff_missedTackle  17426 non-null  int64
# dtypes: int64(7)
# memory usage: 953.1 KB

# %%
tracking_week_1_df.head()
# Out:
#        gameId  playId    nflId     displayName  frameId  \
# 0  2022090800      56  35472.0  Rodger Saffold        1
# 1  2022090800      56  35472.0  Rodger Saffold        2
# 2  2022090800      56  35472.0  Rodger Saffold        3
# 3  2022090800      56  35472.0  Rodger Saffold        4
# 4  2022090800      56  35472.0  Rodger Saffold        5
#
#                          time  jerseyNumber club playDirection      x      y  \
# 0  2022-09-08 20:24:05.200000          76.0  BUF          left  88.37  27.27
# 1  2022-09-08 20:24:05.299999          76.0  BUF          left  88.47  27.13
# 2  2022-09-08 20:24:05.400000          76.0  BUF          left  88.56  27.01
# 3  2022-09-08 20:24:05.500000          76.0  BUF          left  88.64  26.90
# 4  2022-09-08 20:24:05.599999          76.0  BUF          left  88.72  26.80
#
#       s     a   dis       o     dir         event
# 0  1.62  1.15  0.16  231.74  147.90           NaN
# 1  1.67  0.61  0.17  230.98  148.53  pass_arrived
# ...

# %%
tracking_week_1_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1407439 entries, 0 to 1407438
# Data columns (total 17 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   gameId         1407439 non-null  int64
#  1   playId         1407439 non-null  int64
#  2   nflId          1346246 non-null  float64
#  3   displayName    1407439 non-null  object
#  4   frameId        1407439 non-null  int64
#  5   time           1407439 non-null  object
#  6   jerseyNumber   1346246 non-null  float64
#  7   club           1407439 non-null  object
#  8   playDirection  1407439 non-null  object
#  9   x              1407439 non-null  float64
#  10  y              1407439 non-null  float64
#  11  s              1407439 non-null  float64
#  12  a              1407439 non-null  float64
#  13  dis            1407439 non-null  float64
#  14  o              1346397 non-null  float64
#  15  dir            1346397 non-null  float64
# ...

# %%
tracking_week_2_df.head()
# Out:
#        gameId  playId    nflId   displayName  frameId  \
# 0  2022110300      55  38542.0  Fletcher Cox        1
# 1  2022110300      55  38542.0  Fletcher Cox        2
# 2  2022110300      55  38542.0  Fletcher Cox        3
# 3  2022110300      55  38542.0  Fletcher Cox        4
# 4  2022110300      55  38542.0  Fletcher Cox        5
#
#                          time  jerseyNumber club playDirection      x      y  \
# 0  2022-11-03 20:16:30.400000          91.0  PHI         right  35.31  21.25
# 1  2022-11-03 20:16:30.500000          91.0  PHI         right  35.30  21.25
# 2  2022-11-03 20:16:30.599999          91.0  PHI         right  35.29  21.25
# 3  2022-11-03 20:16:30.700000          91.0  PHI         right  35.31  21.24
# 4  2022-11-03 20:16:30.799999          91.0  PHI         right  35.31  21.25
#
#       s     a   dis       o     dir event
# 0  0.25  0.21  0.01  275.05  263.18   NaN
# 1  0.21  0.20  0.02  270.08  264.09   NaN
# 2  0.17  0.18  0.01  267.61  264.78   NaN
# ...

# %%
tracking_week_2_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1371600 entries, 0 to 1371599
# Data columns (total 17 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   gameId         1371600 non-null  int64
#  1   playId         1371600 non-null  int64
#  2   nflId          1311904 non-null  float64
#  3   displayName    1371600 non-null  object
#  4   frameId        1371600 non-null  int64
#  5   time           1371600 non-null  object
#  6   jerseyNumber   1311904 non-null  float64
#  7   club           1371600 non-null  object
#  8   playDirection  1371600 non-null  object
#  9   x              1371600 non-null  float64
#  10  y              1371600 non-null  float64
#  11  s              1371600 non-null  float64
#  12  a              1371600 non-null  float64
#  13  dis            1371600 non-null  float64
#  14  o              1311994 non-null  float64
#  15  dir            1311994 non-null  float64
# ...

# %%
tracking_week_3_df.head()
# Out:
#        gameId  playId    nflId   displayName  frameId  \
# 0  2022110300      55  38542.0  Fletcher Cox        1
# 1  2022110300      55  38542.0  Fletcher Cox        2
# 2  2022110300      55  38542.0  Fletcher Cox        3
# 3  2022110300      55  38542.0  Fletcher Cox        4
# 4  2022110300      55  38542.0  Fletcher Cox        5
#
#                          time  jerseyNumber club playDirection      x      y  \
# 0  2022-11-03 20:16:30.400000          91.0  PHI         right  35.31  21.25
# 1  2022-11-03 20:16:30.500000          91.0  PHI         right  35.30  21.25
# 2  2022-11-03 20:16:30.599999          91.0  PHI         right  35.29  21.25
# 3  2022-11-03 20:16:30.700000          91.0  PHI         right  35.31  21.24
# 4  2022-11-03 20:16:30.799999          91.0  PHI         right  35.31  21.25
#
#       s     a   dis       o     dir event
# 0  0.25  0.21  0.01  275.05  263.18   NaN
# 1  0.21  0.20  0.02  270.08  264.09   NaN
# 2  0.17  0.18  0.01  267.61  264.78   NaN
# ...

# %%
tracking_week_3_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1415788 entries, 0 to 1415787
# Data columns (total 17 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   gameId         1415788 non-null  int64
#  1   playId         1415788 non-null  int64
#  2   nflId          1354232 non-null  float64
#  3   displayName    1415788 non-null  object
#  4   frameId        1415788 non-null  int64
#  5   time           1415788 non-null  object
#  6   jerseyNumber   1354232 non-null  float64
#  7   club           1415788 non-null  object
#  8   playDirection  1415788 non-null  object
#  9   x              1415788 non-null  float64
#  10  y              1415788 non-null  float64
#  11  s              1415788 non-null  float64
#  12  a              1415788 non-null  float64
#  13  dis            1415788 non-null  float64
#  14  o              1354417 non-null  float64
#  15  dir            1354417 non-null  float64
# ...

# %%
tracking_week_4_df.head()
# Out:
#        gameId  playId    nflId   displayName  frameId  \
# 0  2022110300      55  38542.0  Fletcher Cox        1
# 1  2022110300      55  38542.0  Fletcher Cox        2
# 2  2022110300      55  38542.0  Fletcher Cox        3
# 3  2022110300      55  38542.0  Fletcher Cox        4
# 4  2022110300      55  38542.0  Fletcher Cox        5
#
#                          time  jerseyNumber club playDirection      x      y  \
# 0  2022-11-03 20:16:30.400000          91.0  PHI         right  35.31  21.25
# 1  2022-11-03 20:16:30.500000          91.0  PHI         right  35.30  21.25
# 2  2022-11-03 20:16:30.599999          91.0  PHI         right  35.29  21.25
# 3  2022-11-03 20:16:30.700000          91.0  PHI         right  35.31  21.24
# 4  2022-11-03 20:16:30.799999          91.0  PHI         right  35.31  21.25
#
#       s     a   dis       o     dir event
# 0  0.25  0.21  0.01  275.05  263.18   NaN
# 1  0.21  0.20  0.02  270.08  264.09   NaN
# 2  0.17  0.18  0.01  267.61  264.78   NaN
# ...

# %%
tracking_week_4_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1418686 entries, 0 to 1418685
# Data columns (total 17 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   gameId         1418686 non-null  int64
#  1   playId         1418686 non-null  int64
#  2   nflId          1357004 non-null  float64
#  3   displayName    1418686 non-null  object
#  4   frameId        1418686 non-null  int64
#  5   time           1418686 non-null  object
#  6   jerseyNumber   1357004 non-null  float64
#  7   club           1418686 non-null  object
#  8   playDirection  1418686 non-null  object
#  9   x              1418686 non-null  float64
#  10  y              1418686 non-null  float64
#  11  s              1418686 non-null  float64
#  12  a              1418686 non-null  float64
#  13  dis            1418686 non-null  float64
#  14  o              1357361 non-null  float64
#  15  dir            1357361 non-null  float64
# ...

# %%
tracking_week_5_df.head()
# Out:
#        gameId  playId    nflId   displayName  frameId  \
# 0  2022110300      55  38542.0  Fletcher Cox        1
# 1  2022110300      55  38542.0  Fletcher Cox        2
# 2  2022110300      55  38542.0  Fletcher Cox        3
# 3  2022110300      55  38542.0  Fletcher Cox        4
# 4  2022110300      55  38542.0  Fletcher Cox        5
#
#                          time  jerseyNumber club playDirection      x      y  \
# 0  2022-11-03 20:16:30.400000          91.0  PHI         right  35.31  21.25
# 1  2022-11-03 20:16:30.500000          91.0  PHI         right  35.30  21.25
# 2  2022-11-03 20:16:30.599999          91.0  PHI         right  35.29  21.25
# 3  2022-11-03 20:16:30.700000          91.0  PHI         right  35.31  21.24
# 4  2022-11-03 20:16:30.799999          91.0  PHI         right  35.31  21.25
#
#       s     a   dis       o     dir event
# 0  0.25  0.21  0.01  275.05  263.18   NaN
# 1  0.21  0.20  0.02  270.08  264.09   NaN
# 2  0.17  0.18  0.01  267.61  264.78   NaN
# ...

# %%
tracking_week_5_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1476232 entries, 0 to 1476231
# Data columns (total 17 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   gameId         1476232 non-null  int64
#  1   playId         1476232 non-null  int64
#  2   nflId          1412048 non-null  float64
#  3   displayName    1476232 non-null  object
#  4   frameId        1476232 non-null  int64
#  5   time           1476232 non-null  object
#  6   jerseyNumber   1412048 non-null  float64
#  7   club           1476232 non-null  object
#  8   playDirection  1476232 non-null  object
#  9   x              1476232 non-null  float64
#  10  y              1476232 non-null  float64
#  11  s              1476232 non-null  float64
#  12  a              1476232 non-null  float64
#  13  dis            1476232 non-null  float64
#  14  o              1412137 non-null  float64
#  15  dir            1412137 non-null  float64
# ...

# %%
tracking_week_6_df.head()
# Out:
#        gameId  playId    nflId   displayName  frameId  \
# 0  2022110300      55  38542.0  Fletcher Cox        1
# 1  2022110300      55  38542.0  Fletcher Cox        2
# 2  2022110300      55  38542.0  Fletcher Cox        3
# 3  2022110300      55  38542.0  Fletcher Cox        4
# 4  2022110300      55  38542.0  Fletcher Cox        5
#
#                          time  jerseyNumber club playDirection      x      y  \
# 0  2022-11-03 20:16:30.400000          91.0  PHI         right  35.31  21.25
# 1  2022-11-03 20:16:30.500000          91.0  PHI         right  35.30  21.25
# 2  2022-11-03 20:16:30.599999          91.0  PHI         right  35.29  21.25
# 3  2022-11-03 20:16:30.700000          91.0  PHI         right  35.31  21.24
# 4  2022-11-03 20:16:30.799999          91.0  PHI         right  35.31  21.25
#
#       s     a   dis       o     dir event
# 0  0.25  0.21  0.01  275.05  263.18   NaN
# 1  0.21  0.20  0.02  270.08  264.09   NaN
# 2  0.17  0.18  0.01  267.61  264.78   NaN
# ...

# %%
tracking_week_6_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1249365 entries, 0 to 1249364
# Data columns (total 17 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   gameId         1249365 non-null  int64
#  1   playId         1249365 non-null  int64
#  2   nflId          1194996 non-null  float64
#  3   displayName    1249365 non-null  object
#  4   frameId        1249365 non-null  int64
#  5   time           1249365 non-null  object
#  6   jerseyNumber   1194996 non-null  float64
#  7   club           1249365 non-null  object
#  8   playDirection  1249365 non-null  object
#  9   x              1249365 non-null  float64
#  10  y              1249365 non-null  float64
#  11  s              1249365 non-null  float64
#  12  a              1249365 non-null  float64
#  13  dis            1249365 non-null  float64
#  14  o              1195080 non-null  float64
#  15  dir            1195080 non-null  float64
# ...

# %%
tracking_week_7_df.head()
# Out:
#        gameId  playId    nflId   displayName  frameId  \
# 0  2022110300      55  38542.0  Fletcher Cox        1
# 1  2022110300      55  38542.0  Fletcher Cox        2
# 2  2022110300      55  38542.0  Fletcher Cox        3
# 3  2022110300      55  38542.0  Fletcher Cox        4
# 4  2022110300      55  38542.0  Fletcher Cox        5
#
#                          time  jerseyNumber club playDirection      x      y  \
# 0  2022-11-03 20:16:30.400000          91.0  PHI         right  35.31  21.25
# 1  2022-11-03 20:16:30.500000          91.0  PHI         right  35.30  21.25
# 2  2022-11-03 20:16:30.599999          91.0  PHI         right  35.29  21.25
# 3  2022-11-03 20:16:30.700000          91.0  PHI         right  35.31  21.24
# 4  2022-11-03 20:16:30.799999          91.0  PHI         right  35.31  21.25
#
#       s     a   dis       o     dir event
# 0  0.25  0.21  0.01  275.05  263.18   NaN
# 1  0.21  0.20  0.02  270.08  264.09   NaN
# 2  0.17  0.18  0.01  267.61  264.78   NaN
# ...

# %%
tracking_week_7_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1291493 entries, 0 to 1291492
# Data columns (total 17 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   gameId         1291493 non-null  int64
#  1   playId         1291493 non-null  int64
#  2   nflId          1235278 non-null  float64
#  3   displayName    1291493 non-null  object
#  4   frameId        1291493 non-null  int64
#  5   time           1291493 non-null  object
#  6   jerseyNumber   1235278 non-null  float64
#  7   club           1291493 non-null  object
#  8   playDirection  1291493 non-null  object
#  9   x              1291493 non-null  float64
#  10  y              1291493 non-null  float64
#  11  s              1291493 non-null  float64
#  12  a              1291493 non-null  float64
#  13  dis            1291493 non-null  float64
#  14  o              1235421 non-null  float64
#  15  dir            1235421 non-null  float64
# ...

# %%
tracking_week_8_df.head()
# Out:
#        gameId  playId    nflId   displayName  frameId  \
# 0  2022110300      55  38542.0  Fletcher Cox        1
# 1  2022110300      55  38542.0  Fletcher Cox        2
# 2  2022110300      55  38542.0  Fletcher Cox        3
# 3  2022110300      55  38542.0  Fletcher Cox        4
# 4  2022110300      55  38542.0  Fletcher Cox        5
#
#                          time  jerseyNumber club playDirection      x      y  \
# 0  2022-11-03 20:16:30.400000          91.0  PHI         right  35.31  21.25
# 1  2022-11-03 20:16:30.500000          91.0  PHI         right  35.30  21.25
# 2  2022-11-03 20:16:30.599999          91.0  PHI         right  35.29  21.25
# 3  2022-11-03 20:16:30.700000          91.0  PHI         right  35.31  21.24
# 4  2022-11-03 20:16:30.799999          91.0  PHI         right  35.31  21.25
#
#       s     a   dis       o     dir event
# 0  0.25  0.21  0.01  275.05  263.18   NaN
# 1  0.21  0.20  0.02  270.08  264.09   NaN
# 2  0.17  0.18  0.01  267.61  264.78   NaN
# ...

# %%
tracking_week_8_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1406772 entries, 0 to 1406771
# Data columns (total 17 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   gameId         1406772 non-null  int64
#  1   playId         1406772 non-null  int64
#  2   nflId          1345608 non-null  float64
#  3   displayName    1406772 non-null  object
#  4   frameId        1406772 non-null  int64
#  5   time           1406772 non-null  object
#  6   jerseyNumber   1345608 non-null  float64
#  7   club           1406772 non-null  object
#  8   playDirection  1406772 non-null  object
#  9   x              1406772 non-null  float64
#  10  y              1406772 non-null  float64
#  11  s              1406772 non-null  float64
#  12  a              1406772 non-null  float64
#  13  dis            1406772 non-null  float64
#  14  o              1345642 non-null  float64
#  15  dir            1345642 non-null  float64
# ...

# %%
tracking_week_9_df.head()
# Out:
#        gameId  playId    nflId   displayName  frameId  \
# 0  2022110300      55  38542.0  Fletcher Cox        1
# 1  2022110300      55  38542.0  Fletcher Cox        2
# 2  2022110300      55  38542.0  Fletcher Cox        3
# 3  2022110300      55  38542.0  Fletcher Cox        4
# 4  2022110300      55  38542.0  Fletcher Cox        5
#
#                          time  jerseyNumber club playDirection      x      y  \
# 0  2022-11-03 20:16:30.400000          91.0  PHI         right  35.31  21.25
# 1  2022-11-03 20:16:30.500000          91.0  PHI         right  35.30  21.25
# 2  2022-11-03 20:16:30.599999          91.0  PHI         right  35.29  21.25
# 3  2022-11-03 20:16:30.700000          91.0  PHI         right  35.31  21.24
# 4  2022-11-03 20:16:30.799999          91.0  PHI         right  35.31  21.25
#
#       s     a   dis       o     dir event
# 0  0.25  0.21  0.01  275.05  263.18   NaN
# 1  0.21  0.20  0.02  270.08  264.09   NaN
# 2  0.17  0.18  0.01  267.61  264.78   NaN
# ...

# %%
tracking_week_9_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1150023 entries, 0 to 1150022
# Data columns (total 17 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   gameId         1150023 non-null  int64
#  1   playId         1150023 non-null  int64
#  2   nflId          1100022 non-null  float64
#  3   displayName    1150023 non-null  object
#  4   frameId        1150023 non-null  int64
#  5   time           1150023 non-null  object
#  6   jerseyNumber   1100022 non-null  float64
#  7   club           1150023 non-null  object
#  8   playDirection  1150023 non-null  object
#  9   x              1150023 non-null  float64
#  10  y              1150023 non-null  float64
#  11  s              1150023 non-null  float64
#  12  a              1150023 non-null  float64
#  13  dis            1150023 non-null  float64
#  14  o              1100062 non-null  float64
#  15  dir            1100062 non-null  float64
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Example with tracking_week_1_df
print(tracking_week_1_df.head())
print(tracking_week_1_df.info())
print(tracking_week_1_df.describe())
# Out:
#        gameId  playId    nflId     displayName  frameId  \
# 0  2022090800      56  35472.0  Rodger Saffold        1
# 1  2022090800      56  35472.0  Rodger Saffold        2
# 2  2022090800      56  35472.0  Rodger Saffold        3
# 3  2022090800      56  35472.0  Rodger Saffold        4
# 4  2022090800      56  35472.0  Rodger Saffold        5
#
#                          time  jerseyNumber club playDirection      x      y  \
# 0  2022-09-08 20:24:05.200000          76.0  BUF          left  88.37  27.27
# 1  2022-09-08 20:24:05.299999          76.0  BUF          left  88.47  27.13
# 2  2022-09-08 20:24:05.400000          76.0  BUF          left  88.56  27.01
# 3  2022-09-08 20:24:05.500000          76.0  BUF          left  88.64  26.90
# 4  2022-09-08 20:24:05.599999          76.0  BUF          left  88.72  26.80
#
#       s     a   dis       o     dir         event
# 0  1.62  1.15  0.16  231.74  147.90           NaN
# 1  1.67  0.61  0.17  230.98  148.53  pass_arrived
# ...

# %%
# Distribution of speed ('s') across the tracking data
sns.histplot(tracking_week_1_df['s'], bins=30)
plt.xlabel('Speed')
plt.ylabel('Frequency')
plt.title('Distribution of Player Speed')
plt.show()

# %%
# Example: Calculate distance to the center line
tracking_week_1_df['distance_to_center'] = tracking_week_1_df['y'].apply(lambda y: abs(50 - y))

# %%
# Scatter plot to observe player positions
plt.scatter(tracking_week_1_df['x'], tracking_week_1_df['y'])
plt.xlabel('X Position')
plt.ylabel('Y Position')
plt.title('Player Positions on the Field')
plt.show()

# %% [markdown]
# # For example, analyzing player speed during successful tackles
# # This will require merging and filtering data based on event types and success criteria

# %%
# Example of filtering data for tackle events
tackle_events = tracking_week_1_df[tracking_week_1_df['event'] == 'tackle']

# %%
# Analyzing the distribution of speed during tackle events
sns.histplot(tackle_events['s'], kde=True)
plt.title('Distribution of Player Speed during Tackles')
plt.xlabel('Speed')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # This would require more complex calculations and possibly merging with play data
# # Example: Calculating the distance from the ball carrier and comparing with tackle success

# %%
# Example: Visualizing player positions during tackles
plt.scatter(tackle_events['x'], tackle_events['y'])
plt.title('Player Positions during Tackles')
plt.xlabel('X Position')
plt.ylabel('Y Position')
plt.show()

# %%
# Example of filtering data for tackle events
tackle_events = tracking_week_1_df[tracking_week_1_df['event'] == 'tackle']

# %%
# Analyzing the distribution of speed during tackle events
sns.histplot(tackle_events['s'], kde=True)
plt.title('Distribution of Player Speed during Tackles')
plt.xlabel('Speed')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Certainly! The histogram you've provided appears to show the distribution of player speeds during tackles. From the visualization, it seems that the speed distribution is skewed to the right with a peak at the lower speed values, suggesting that most tackles happen at lower speeds.

# %%
# Example: Visualizing player positions during tackles
plt.scatter(tackle_events['x'], tackle_events['y'])
plt.title('Player Positions during Tackles')
plt.xlabel('X Position')
plt.ylabel('Y Position')
plt.show()

# %%
# Example using tracking data from week 1
# This code assumes there's a common key between the dataframes. 
# You'll need to identify the correct keys (e.g., 'gameId', 'playId', 'nflId') to merge properly.

tackles_with_tracking = pd.merge(tackles_df, tracking_week_1_df, on=['gameId', 'playId'])

# %%
# Filter for tackling events if 'event' column exists and contains tackle information
tackle_events = tackles_with_tracking[tackles_with_tracking['event'].str.contains('tackle', na=False)]

# Now you can calculate mean, median, and standard deviation of speed during tackles
mean_speed = tackle_events['s'].mean()
median_speed = tackle_events['s'].median()
std_dev_speed = tackle_events['s'].std()

print(f"Mean Speed during Tackles: {mean_speed}")
print(f"Median Speed during Tackles: {median_speed}")
print(f"Standard Deviation of Speed during Tackles: {std_dev_speed}")
# Out:
# Mean Speed during Tackles: 2.514849843805939
# Median Speed during Tackles: 2.2
# Standard Deviation of Speed during Tackles: 1.631266702764987

# %%
# Merge tackles data with tracking data for week 1
merged_data_week_1 = pd.merge(tackles_df, tracking_week_1_df, on=['gameId', 'playId'])

# %%
mean_speed = tackle_events_week_1['s'].mean()
median_speed = tackle_events_week_1['s'].median()
std_dev_speed = tackle_events_week_1['s'].std()

print(f"Mean Speed: {mean_speed}")
print(f"Median Speed: {median_speed}")
print(f"Standard Deviation of Speed: {std_dev_speed}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Coding_local\Data Science Projects\NFL Kaggle\nfl-big-data-bowl-2024\tables.ipynb Cell 75 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Coding_local/Data%20Science%20Projects/NFL%20Kaggle/nfl-big-data-bowl-2024/tables.ipynb#Y161sZmlsZQ%3D%3D?line=0'>1</a> mean_speed = tackle_events_week_1['s'].mean()
#       <a href='vscode-notebook-cell:/c%3A/Coding_local/Data%20Science%20Projects/NFL%20Kaggle/nfl-big-data-bowl-2024/tables.ipynb#Y161sZmlsZQ%3D%3D?line=1'>2</a> median_speed = tackle_events_week_1['s'].median()
#       <a href='vscode-notebook-cell:/c%3A/Coding_local/Data%20Science%20Projects/NFL%20Kaggle/nfl-big-data-bowl-2024/tables.ipynb#Y161sZmlsZQ%3D%3D?line=2'>3</a> std_dev_speed = tackle_events_week_1['s'].std()
#
# NameError: name 'tackle_events_week_1' is not defined
